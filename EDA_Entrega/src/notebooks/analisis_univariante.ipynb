# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
health = pd.read_csv(r"C:\Users\patri\REPO_PRUEBA\ONLINE_DS_THEBRIDGE_Patricia_Diez\EDA_Entrega\src\data\health_cleaned.csv")
health
# Out:
#      Employee_ID  Age      Gender           Job_Role    Industry  \
# 0        EMP0001   32  Non-Binary                 Hr  Healthcare
# 1        EMP0002   40      Female     Data Scientist          It
# 2        EMP0003   59  Non-Binary  Software Engineer   Education
# 3        EMP0004   27        Male  Software Engineer     Finance
# 4        EMP0005   49        Male              Sales  Consulting
# ...          ...  ...         ...                ...         ...
# 4995     EMP4996   32        Male              Sales  Consulting
# 4996     EMP4997   39      Female              Sales  Healthcare
# 4997     EMP4998   42      Female              Sales  Healthcare
# 4998     EMP4999   27      Female              Sales  Healthcare
# 4999     EMP5000   29        Male                 Hr          It
#
#       Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                      13        Hybrid                     47
# ...

# %% [markdown]
# #VARIABLES CATEGORICAS:
# Employee_ID,
# Job_Role,
# Industry,
# Work_location,
# Stress_Level,
# Mental_Health_Condition,
# Acess_to_Mental_Health_Resources,
# Productivity_Change,
# Satisfaction_with_Remote_Work,
# Physical_Activity,
# Sleep_Quality,
# Region

# %%
from bootcampviztools import *

# %%
#relative = False
pinta_distribucion_categoricas(health, ["Job_Role", "Industry", "Work_Location", "Stress_Level", "Mental_Health_Condition", 
                       "Access_to_Mental_Health_Resources", "Productivity_Change", "Satisfaction_with_Remote_Work", "Physical_Activity",
                       "Sleep_Quality", "Region"], relativa=False, mostrar_valores=True)

# %%
#relative = True
pinta_distribucion_categoricas(health, ["Job_Role", "Industry", "Work_Location", "Stress_Level", "Mental_Health_Condition", 
                       "Access_to_Mental_Health_Resources", "Productivity_Change", "Satisfaction_with_Remote_Work", "Physical_Activity",
                       "Sleep_Quality", "Region"], relativa=True, mostrar_valores=True)

# %% [markdown]
# #VARIABLES NUMERICAS:
# Age,
# Years_of_Experience,
# Hours_Worked_Per_Week,
# Number_of_Virtual_Meetings,
# Work_life_Balance_Rating,
# Social_Isolation_Rating,
# Company_Support_for_Remote_Work

# %%
numerical = health.select_dtypes(include=["int64", "float64"]).columns
numerical
# Out:
# Index(['Age', 'Years_of_Experience', 'Hours_Worked_Per_Week',
#        'Number_of_Virtual_Meetings', 'Work_Life_Balance_Rating',
#        'Social_Isolation_Rating', 'Company_Support_for_Remote_Work'],
#       dtype='object')

# %%
health.describe()
# Out:
#                Age  Years_of_Experience  Hours_Worked_Per_Week  \
# count  5000.000000          5000.000000            5000.000000
# mean     40.995000            17.810200              39.614600
# std      11.296021            10.020412              11.860194
# min      22.000000             1.000000              20.000000
# 25%      31.000000             9.000000              29.000000
# 50%      41.000000            18.000000              40.000000
# 75%      51.000000            26.000000              50.000000
# max      60.000000            35.000000              60.000000
#
#        Number_of_Virtual_Meetings  Work_Life_Balance_Rating  \
# count                 5000.000000               5000.000000
# mean                     7.559000                  2.984200
# std                      4.636121                  1.410513
# min                      0.000000                  1.000000
# 25%                      4.000000                  2.000000
# ...

# %%
plot_multiple_boxplots(health, ['Age', 'Years_of_Experience', 'Hours_Worked_Per_Week',
       'Number_of_Virtual_Meetings', 'Work_Life_Balance_Rating',
       'Social_Isolation_Rating', 'Company_Support_for_Remote_Work'], 2)
