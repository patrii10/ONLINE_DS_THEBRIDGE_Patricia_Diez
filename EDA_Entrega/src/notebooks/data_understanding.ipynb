# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
health = pd.read_csv(r"C:\Users\patri\REPO_PRUEBA\ONLINE_DS_THEBRIDGE_Patricia_Diez\EDA_Entrega\src\data\health_cleaned.csv")
health.head(2)
# Out:
#   Employee_ID  Age      Gender        Job_Role    Industry  \
# 0     EMP0001   32  Non-Binary              Hr  Healthcare
# 1     EMP0002   40      Female  Data Scientist          It
#
#    Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                   13        Hybrid                     47
# 1                    3        Remote                     52
#
#    Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 0                           7                         2       Medium
# 1                           4                         1       Medium
#
#   Mental_Health_Condition Access_to_Mental_Health_Resources  \
# 0              Depression                                No
# 1                 Anxiety                                No
#
#   Productivity_Change  Social_Isolation_Rating Satisfaction_with_Remote_Work  \
# 0            Decrease                        1                   Unsatisfied
# ...

# %% [markdown]
# |Columna/Variable|Descripción|Tipo_de_Variable|Importancia inicial|Nota|Posible transformación|
# |-|-|-|-|-|-|
# |Employee_ID|id identificativo de la persona encuestada|categórica nominal|baja|es solo un identificador||
# |Age|edad de la persona encuestada|numérica discreta|alta|la edad puede influir en la salud mental|se pueden meter en rangos|
# |Gender|sexo de la persona encuestada|categórica nominal|media|puede influir en el análisis||
# |Job_role|rol en la empresa|categórica nominal|alta|puede tener algo que ver el rol con el estrés y la salud mental||
# |Industry|industria en la que trabaja|categórica nominal|media|de nuevo, puede influir en el estrés||
# |Years_of_Experience|años que lleva trabajando|numérica discreta|baja|||
# |Work_location|si es híbrido, remoto o en el presencial el trabajo|categórica nominal|muy alta|||
# |Hours_Worked_Per_Week|horas de trabajo que hacen a la semana|numérica continua|alta|el número de horas puede influir en la salud mental||
# |Number_of_Virtual_Meetings|cantidad de meetings que tienen|numérica discreta|media|¿puede influir también en el estrés?|
# |Work_life_Balance_Rating|percepción de equilibrio entre vida personal y trabajo|numérica continua|muy alta|||
# |Stress_Level|nivel de estrés que sufre el encuestad@|categórica ordinal|muy alta|||
# |Mental_Health_Condition|estado de la salud mental|categórica nominal|muy alta||podemos añadir una columna que las haga binarias(tiene condition/ no tiene)|
# |Acess_to_Mental_Health_Resources|si tienen acceso a recibir ayuda externa asociada con la salud mental|binaria|alta|||
# |Productivity_Change|si notan algún cambio en su productividad|categórica nominal|media|||
# |Social_Isolation_Rating|cómo de aislados se sienten socialmente|numérica discreta|media|||
# |Satisfaction_with_Remote_Work|nivel de stafisfacción con su trabajo|categórica ordinal|alta|||
# |Company_Support_for_Remote_Work|el apoyo que han recibido por parte de la empresa para hacer teletrabajo|numérica discreta|media||
# |Physical_Activity|la cantidad de veces que han deporte|binaria|media|el deporte libera endorfinas, por lo que puede ayudar a la salud mental||
# |Sleep_Quality|calidad del sueño|categórica ordinal|alta|||
# |Region|región de los encuestad@s|categórica nominal|media|puede ser interesante ver si hay regiones en las que la salud mental es mejor o peor||

# %%
health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Employee_ID                        5000 non-null   object
#  1   Age                                5000 non-null   int64
#  2   Gender                             5000 non-null   object
#  3   Job_Role                           5000 non-null   object
#  4   Industry                           5000 non-null   object
#  5   Years_of_Experience                5000 non-null   int64
#  6   Work_Location                      5000 non-null   object
#  7   Hours_Worked_Per_Week              5000 non-null   int64
#  8   Number_of_Virtual_Meetings         5000 non-null   int64
#  9   Work_Life_Balance_Rating           5000 non-null   int64
#  10  Stress_Level                       5000 non-null   object
# ...

# %%
health.Mental_Health_Condition.unique()
# Out:
# array(['Depression', 'Anxiety', nan, 'Burnout'], dtype=object)

# %%
#Mental_Health_Condition: Podría binarizarse en casos como Has condition (Depression, Anxiety, Burnout) y No condition (NaN o Missing)
health["Has_condition"] = np.where(health["Mental_Health_Condition"].notna(), "Yes", "No info")

# %%
health
# Out:
#      Employee_ID  Age      Gender           Job_Role    Industry  \
# 0        EMP0001   32  Non-Binary                 Hr  Healthcare
# 1        EMP0002   40      Female     Data Scientist          It
# 2        EMP0003   59  Non-Binary  Software Engineer   Education
# 3        EMP0004   27        Male  Software Engineer     Finance
# 4        EMP0005   49        Male              Sales  Consulting
# ...          ...  ...         ...                ...         ...
# 4995     EMP4996   32        Male              Sales  Consulting
# 4996     EMP4997   39      Female              Sales  Healthcare
# 4997     EMP4998   42      Female              Sales  Healthcare
# 4998     EMP4999   27      Female              Sales  Healthcare
# 4999     EMP5000   29        Male                 Hr          It
#
#       Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                      13        Hybrid                     47
# ...
