# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
health = pd.read_csv(r"C:\Users\patri\REPO_PRUEBA\ONLINE_DS_THEBRIDGE_Patricia_Diez\EDA_Entrega\src\data\Impact_of_Remote_Work_on_Mental_Health.csv")
health
# Out:
#      Employee_ID  Age      Gender           Job_Role    Industry  \
# 0        EMP0001   32  Non-binary                 HR  Healthcare
# 1        EMP0002   40      Female     Data Scientist          IT
# 2        EMP0003   59  Non-binary  Software Engineer   Education
# 3        EMP0004   27        Male  Software Engineer     Finance
# 4        EMP0005   49        Male              Sales  Consulting
# ...          ...  ...         ...                ...         ...
# 4995     EMP4996   32        Male              Sales  Consulting
# 4996     EMP4997   39      Female              Sales  Healthcare
# 4997     EMP4998   42      Female              Sales  Healthcare
# 4998     EMP4999   27      Female              Sales  Healthcare
# 4999     EMP5000   29        Male                 HR          IT
#
#       Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                      13        Hybrid                     47
# ...

# %%
health.info()
#vemos que hay unn problema en pyshical activity. vamos a mirarla
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Employee_ID                        5000 non-null   object
#  1   Age                                5000 non-null   int64
#  2   Gender                             5000 non-null   object
#  3   Job_Role                           5000 non-null   object
#  4   Industry                           5000 non-null   object
#  5   Years_of_Experience                5000 non-null   int64
#  6   Work_Location                      5000 non-null   object
#  7   Hours_Worked_Per_Week              5000 non-null   int64
#  8   Number_of_Virtual_Meetings         5000 non-null   int64
#  9   Work_Life_Balance_Rating           5000 non-null   int64
#  10  Stress_Level                       5000 non-null   object
# ...

# %%
print(health.Physical_Activity.unique())
print(health.Physical_Activity.isna().sum())
# Out:
# ['Weekly' nan 'Daily']
# 1629

# %%
#como no tengo muy claro todavía que hacer con esa columna (eliminarla o reemplazar los datos), por utilidad en el análisis, voy a reemplaar el nan por missing.
health['Physical_Activity'] = health['Physical_Activity'].fillna('Missing')
health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Employee_ID                        5000 non-null   object
#  1   Age                                5000 non-null   int64
#  2   Gender                             5000 non-null   object
#  3   Job_Role                           5000 non-null   object
#  4   Industry                           5000 non-null   object
#  5   Years_of_Experience                5000 non-null   int64
#  6   Work_Location                      5000 non-null   object
#  7   Hours_Worked_Per_Week              5000 non-null   int64
#  8   Number_of_Virtual_Meetings         5000 non-null   int64
#  9   Work_Life_Balance_Rating           5000 non-null   int64
#  10  Stress_Level                       5000 non-null   object
# ...

# %%
#OUTLIERS

# %%
# Boxplots de todas las columnas numéricas
cols_to_plot = ['Age', 'Years_of_Experience', 'Hours_Worked_Per_Week', 'Number_of_Virtual_Meetings']
for col in cols_to_plot:
    sns.boxplot(x=health[col])
    plt.title(f'Boxplot de {col}')
    plt.show()

# %%
#Genial! No hay outliers

# %%
#Verificamos que no haya duplicados 
health.duplicated().sum()
# Out:
# np.int64(0)

# %%
#verificamos que todos los datos estan en formato correcto
health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Employee_ID                        5000 non-null   object
#  1   Age                                5000 non-null   int64
#  2   Gender                             5000 non-null   object
#  3   Job_Role                           5000 non-null   object
#  4   Industry                           5000 non-null   object
#  5   Years_of_Experience                5000 non-null   int64
#  6   Work_Location                      5000 non-null   object
#  7   Hours_Worked_Per_Week              5000 non-null   int64
#  8   Number_of_Virtual_Meetings         5000 non-null   int64
#  9   Work_Life_Balance_Rating           5000 non-null   int64
#  10  Stress_Level                       5000 non-null   object
# ...

# %%
# Detectar valores únicos en columnas categóricas
for col in health.select_dtypes(include='object').columns:
    print(f"Valores únicos en {col}:")
    print(health[col].unique())
    print()
# Out:
# Valores únicos en Employee_ID:
# ['EMP0001' 'EMP0002' 'EMP0003' ... 'EMP4998' 'EMP4999' 'EMP5000']
#
# Valores únicos en Gender:
# ['Non-binary' 'Female' 'Male' 'Prefer not to say']
#
# Valores únicos en Job_Role:
# ['HR' 'Data Scientist' 'Software Engineer' 'Sales' 'Marketing' 'Designer'
#  'Project Manager']
#
# Valores únicos en Industry:
# ['Healthcare' 'IT' 'Education' 'Finance' 'Consulting' 'Manufacturing'
#  'Retail']
#
# Valores únicos en Work_Location:
# ['Hybrid' 'Remote' 'Onsite']
#
# Valores únicos en Stress_Level:
# ['Medium' 'High' 'Low']
#
# Valores únicos en Mental_Health_Condition:
# ['Depression' 'Anxiety' nan 'Burnout']
#
# Valores únicos en Access_to_Mental_Health_Resources:
# ['No' 'Yes']
#
# Valores únicos en Productivity_Change:
# ['Decrease' 'Increase' 'No Change']
#
# Valores únicos en Satisfaction_with_Remote_Work:
# ['Unsatisfied' 'Satisfied' 'Neutral']
#
# Valores únicos en Physical_Activity:
# ['Weekly' 'Missing' 'Daily']
#
# ...

# %%
cols_to_normalize = ['Gender', 'Job_Role', 'Industry', 'Work_Location', 'Stress_Level',
                     'Mental_Health_Condition', 'Access_to_Mental_Health_Resources',
                     'Productivity_Change', 'Satisfaction_with_Remote_Work', 
                     'Physical_Activity', 'Sleep_Quality', 'Region']

for col in cols_to_normalize:
    health[col] = health[col].str.strip().str.title()

# %%
#en Mental health condition hay muchos nan, pero lo voy 
# a analizar más en profundidad en el análisis univariante para ver si puedo sacar algo de ello.

# %%
#Mental_Health_Condition: Podría binarizarse en casos como Has condition (Depression, Anxiety, Burnout) y No condition (NaN o Missing)
health["Has_condition"] = np.where(health["Mental_Health_Condition"].notna(), "Yes", "No info")

# %%
health.to_csv('health_cleaned.csv', index=False)
