# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect(r'C:\Users\patri\REPO_PRUEBA\ONLINE_DS_THEBRIDGE_Patricia_Diez\Sprint_08\challenge_06\sql-murder-mystery.db')
cursor = conn.cursor()

# %%
def sql_query(query):
    cursor.execute(query)
    if cursor.description:  
        ans = cursor.fetchall()
        names = [description[0] for description in cursor.description]
        return pd.DataFrame(ans, columns=names)
    else:
        conn.commit() 
        return None

# %%
# PRIMERA QUERY 
query = '''
SELECT date, type, description, city 
FROM crime_scene_report
WHERE city = "SQL City" AND date = "20180115" AND type = "murder"
'''

sql_query(query)
# Out:
#        date    type                                        description  \
# 0  20180115  murder  Security footage shows that there were 2 witne...
#
#        city
# 0  SQL City

# %%
#Para sacar el nombre de Annabel y sus datos 

query = '''  
SELECT *
FROM person
ORDER BY name ASC
'''

sql_query(query)
# Out:
#           id               name  license_id  address_number  \
# 0      49350      Aaron Brunken      384559            3734
# 1      96053        Aaron Elery      552786            2225
# 2      86834      Aaron Larcher      338012             356
# 3      71064      Aaron Reitler      838065            2939
# 4      80579      Abbey Staniec      785801            2379
# ...      ...                ...         ...             ...
# 10006  95979        Zora Santio      441152            2265
# 10007  57987     Zoraida Peroni      829852            1874
# 10008  59504  Zoraida Stakemann      412588             628
# 10009  68204       Zula Brisbin      702740            1424
# 10010  63255    Zulema Luescher      664031             230
#
#       address_street_name        ssn
# 0       Fourteen Mile Way  648235164
# 1               Castle Rd  734477633
# 2             Harwalt Way  662734103
# 3               Cooke Ave  591644629
# 4         Pipers Glen Way  193845734
# ...

# %%
#Ya tenemos su nombre completo

query = '''  
SELECT *
FROM person
WHERE name ="Annabel Miller"
'''

sql_query(query)
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  16371  Annabel Miller      490173             103        Franklin Ave
#
#          ssn
# 0  318771143

# %%
#2o witness
query = '''  
SELECT *
FROM person
WHERE address_street_name LIKE "%North%"
'''  
sql_query(query)
# Out:
#         id               name  license_id  address_number  \
# 0    10010          Muoi Cary      385336             741
# 1    10455      Sally Claborn      508546            2621
# 2    11663   Wilmer Stansifer      884012            2034
# 3    12107      Agatha Seddon      466755             740
# 4    12573  Granville Moznett      881484            1023
# ..     ...                ...         ...             ...
# 164  98593        Jonah Toner      578982            2947
# 165  98812    Cecil Droneburg      944474            2680
# 166  99206     Delois Coderre      581017             713
# 167  99280      Rosaria Krein      325603            3077
# 168  99826       Ivy Kazarian      994470             892
#
#            address_street_name        ssn
# 0              Northwestern Dr  828638512
# 1             North Croydon Dr  659962475
# 2           North Ellsworth Dr  998323983
# 3               Northstead Way  636352179
# 4             North Walnut Ave  662617693
# ...

# %%
query = '''  
SELECT *
FROM person
WHERE address_street_name = "Northwestern Dr"
ORDER BY address_number DESC
'''

sql_query(query)
# ya se quien es el segundo witness (Morty Schapiro)
# Out:
#        id                  name  license_id  address_number  \
# 0   14887        Morty Schapiro      118009            4919
# 1   17729        Lasonya Wildey      439686            3824
# 2   53890        Sophie Tiberio      957671            3755
# 3   73368        Torie Thalmann      773862            3697
# 4   96595         Coretta Cubie      303645            3631
# 5   19420           Cody Schiel      890431            3524
# 6   93509        Emmitt Aceuedo      916706            3491
# 7   87456   Leonora Wolfsberger      215868            3483
# 8   36378        Freddie Ellzey      267882            3449
# 9   53076           Boris Bijou      664914            3327
# 10  28360        Rashad Cascone      924517            3212
# 11  23044          Val Portlock      924989            3143
# 12  51114     Christena Saffell      814284            3055
# 13  68690            Yer Modest      852404            3046
# 14  44004           Alison Eska      327797            2951
# ...

# %%
#Leemos el transcript de Annabel

query = '''  
SELECT person_id, transcript 
FROM interview
WHERE person_id = "16371"
'''  

sql_query(query)
# Out:
#    person_id                                         transcript
# 0      16371  I saw the murder happen, and I recognized the ...

# %%
#Leemos el transcript de witness n2: 
query = '''  
SELECT person_id, transcript 
FROM interview
WHERE person_id = "14887"
''' 

sql_query(query)
# Out:
#    person_id                                         transcript
# 0      14887  I heard a gunshot and then saw a man run out. ...

# %%
#Buscamos a una persona que haya estado em esas fechas en el gimnasio y cuyo id contenga 48Z
query = '''  
SELECT *
FROM get_fit_now_check_in
WHERE check_in_date = "20180109" AND membership_id LIKE "%48Z%"
''' 

sql_query(query)
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         48Z7A       20180109           1600            1730
# 1         48Z55       20180109           1530            1700

# %%
#Buscamos en la tabla de cliente el nombre 
query = '''  
SELECT *
FROM get_fit_now_member
WHERE id LIKE "%48Z%" AND membership_status = "gold"
'''

sql_query(query)
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z7A      28819   Joe Germuska               20160305              gold
# 1  48Z55      67318  Jeremy Bowers               20160101              gold

# %%
#Buscamos su matrícula id : 
query = '''  
SELECT *
FROM person
WHERE id = 28819 OR id = 67318
'''

sql_query(query)
# Out:
#       id           name  license_id  address_number    address_street_name  \
# 0  28819   Joe Germuska      173289             111                Fisk Rd
# 1  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#          ssn
# 0  138909730
# 1  871539279

# %%
#buscamos el numero de matricula. Y encontramos al delincuente: 
query = '''  
SELECT *
FROM drivers_license 
WHERE plate_number LIKE "%H42W%" AND gender = "male" 
	AND id = 173289 or id = 423327
'''

sql_query(query)

#JEREMY BOWERS!
# Out:
#        id  age  height eye_color hair_color gender plate_number   car_make  \
# 0  423327   30      70     brown      brown   male       0H42W2  Chevrolet
#
#   car_model
# 0  Spark LS

# %%
query = '''  
INSERT INTO solution VALUES (1, 'Jeremy Bowers');
'''

sql_query(query)

# %%
#Encontramos al murderer

query = '''  
SELECT value FROM solution;
'''  

sql_query(query)
# Out:
#                                                value
# 0  Congrats, you found the murderer! But wait, th...

# %%
#Seguimos buscando al verdadero sospechoso: 
query = '''  
SELECT *
FROM interview
WHERE person_id = 67318
'''  

sql_query(query)
# Out:
#    person_id                                         transcript
# 0      67318  I was hired by a woman with a lot of money. I ...

# %%
#Con la descripción buscamos en license
query = '''  
SELECT *
FROM drivers_license
WHERE hair_color = "red" AND car_make = "Tesla" AND gender = "female"
'''

sql_query(query)
# Out:
#        id  age  height eye_color hair_color  gender plate_number car_make  \
# 0  202298   68      66     green        red  female       500123    Tesla
# 1  291182   65      66      blue        red  female       08CM64    Tesla
# 2  918773   48      65     black        red  female       917UU3    Tesla
#
#   car_model
# 0   Model S
# 1   Model S
# 2   Model S

# %%
#Con el license_id sacamos el person_id
query = '''  
SELECT *
FROM person
WHERE license_id = 202298 OR license_id = 291182 OR license_id = 918773
'''  

sql_query(query)
# Out:
#       id              name  license_id  address_number address_street_name  \
# 0  78881          Red Korb      918773             107         Camerata Dr
# 1  90700     Regina George      291182             332           Maple Ave
# 2  99716  Miranda Priestly      202298            1883          Golden Ave
#
#          ssn
# 0  961388910
# 1  337169072
# 2  987756388

# %%
# Un vez tenemos el id buscamos el evento

query = '''  
SELECT *
FROM facebook_event_checkin
WHERE date LIKE "201712%" AND event_name LIKE "%concert%" AND 
(person_id = 78881 OR person_id = 90700 OR person_id = 99716)
'''

sql_query(query)
# Out:
#    person_id  event_id            event_name      date
# 0      99716      1143  SQL Symphony Concert  20171206
# 1      99716      1143  SQL Symphony Concert  20171212
# 2      99716      1143  SQL Symphony Concert  20171229

# %%
#Verdadera delincuente

query = '''  
INSERT INTO solution VALUES (1, 'Miranda Priestly');
''' 
sql_query(query)

# %%
query = '''   
SELECT value FROM solution;
'''   

sql_query(query)
# Out:
#                                                value
# 0  Congrats, you found the brains behind the murd...
